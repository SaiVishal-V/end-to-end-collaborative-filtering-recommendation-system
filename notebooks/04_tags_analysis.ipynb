# %% [markdown]
# This notebook helps in understanding the purpose of the other two notebooks tags and links

# %%
import pandas as pd

# %%
tags = pd.read_csv(r"E:\end-to-end-collaborative-filtering-recommendation-system\data\tags.csv")
links = pd.read_csv(r"E:\end-to-end-collaborative-filtering-recommendation-system\data\links.csv")

# %% [markdown]
# Performing the Basic Data analysis for both the Tags and Links dataset

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tags.tail()
# Out:
#       userId  movieId               tag   timestamp
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags.isnull().sum()
# Out:
# userId       0
# movieId      0
# tag          0
# timestamp    0
# dtype: int64

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     3683 non-null   int64
#  1   movieId    3683 non-null   int64
#  2   tag        3683 non-null   object
#  3   timestamp  3683 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 115.2+ KB

# %%
tags.shape
# Out:
# (3683, 4)

# %%
#tags["movie"]

# %%
tags["movieId"].nunique()
# Out:
# 1572

# %%
tags["userId"].count()
# Out:
# np.int64(3683)

# %%
tags["userId"].nunique()
# Out:
# 58

# %%
tags["userId"].duplicated().sum()
# Out:
# np.int64(3625)

# %% [markdown]
# Conclusion of TAGS Dataset
#
# 1. THis dataset contains columns userId, MovieId, tag, timestamp
# 2. No missing values
# 3. Shape :- (3683, 4)
# 4. Out of 3683 userIds only 58 are unique and in movies 1572
# 5. Duplicate UserId sum 3625

# %% [markdown]
# Similarly for links

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
links.shape
# Out:
# (9742, 3)

# %%
links.columns
# Out:
# Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')

# %%
links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   imdbId   9742 non-null   int64
#  2   tmdbId   9734 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 228.5 KB

# %%
links.isnull().sum()
# Out:
# movieId    0
# imdbId     0
# tmdbId     8
# dtype: int64

# %%
links.duplicated().sum()
# Out:
# np.int64(0)
