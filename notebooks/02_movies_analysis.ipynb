# %% [markdown]
# This notebook contains the analysis of the movies.csv dataset

# %%
import pandas as pd

# %%
#Loading the dataset
movies = pd.read_csv(r"E:\end-to-end-collaborative-filtering-recommendation-system\data\movies.csv")

# %%
#Basic Info
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres Primary Genre
# 0  Adventure|Animation|Children|Comedy|Fantasy     Adventure
# 1                   Adventure|Children|Fantasy     Adventure
# 2                               Comedy|Romance        Comedy
# 3                         Comedy|Drama|Romance        Comedy
# 4                                       Comedy        Comedy

# %%
movies.tail()
# Out:
#       movieId                                      title  \
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                genres Primary Genre
# 9737  Action|Animation|Comedy|Fantasy        Action
# 9738         Animation|Comedy|Fantasy     Animation
# 9739                            Drama         Drama
# 9740                 Action|Animation        Action
# 9741                           Comedy        Comedy

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movieId        9742 non-null   int64
#  1   title          9742 non-null   object
#  2   genres         9742 non-null   object
#  3   Primary Genre  9742 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 304.6+ KB

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres', 'Primary Genre'], dtype='object')

# %%
movies.shape
# Out:
# (9742, 4)

# %%
movies.describe(include="all")
# Out:
#               movieId            title genres Primary Genre
# count     9742.000000             9742   9742          9742
# unique            NaN             9737    951            19
# top               NaN  Saturn 3 (1980)  Drama        Comedy
# freq              NaN                2   1053          2779
# mean     42200.353623              NaN    NaN           NaN
# std      52160.494854              NaN    NaN           NaN
# min          1.000000              NaN    NaN           NaN
# 25%       3248.250000              NaN    NaN           NaN
# 50%       7300.000000              NaN    NaN           NaN
# 75%      76232.000000              NaN    NaN           NaN
# max     193609.000000              NaN    NaN           NaN

# %%
movies.isnull().sum() #Check missing rows
# Out:
# movieId          0
# title            0
# genres           0
# Primary Genre    0
# dtype: int64

# %%
movies.duplicated().sum() #Check duplicates
# Out:
# np.int64(0)

# %%
movies['movieId'].nunique()
# Out:
# 9742

# %%
movies['genres'].head()
# Out:
# 0    Adventure|Animation|Children|Comedy|Fantasy
# 1                     Adventure|Children|Fantasy
# 2                                 Comedy|Romance
# 3                           Comedy|Drama|Romance
# 4                                         Comedy
# Name: genres, dtype: object
