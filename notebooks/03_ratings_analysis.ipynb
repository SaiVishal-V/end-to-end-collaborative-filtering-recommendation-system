# %% [markdown]
# This dataset answers the questions :-
#
# 1. How many users exist?
# 2. How many ratings exist?
# 3. Which movies are rated the most?
# 4. Which users rate the most movies?
# 5. What rating do people usually give?

# %%
import pandas as pd

# %%
ratings = pd.read_csv(r"E:\end-to-end-collaborative-filtering-recommendation-system\data\ratings.csv")

# %% [markdown]
# Basic Info

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings.tail()
# Out:
#         userId  movieId  rating   timestamp
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415

# %%
ratings.shape
# Out:
# (100836, 4)

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %% [markdown]
# Checking for Duplicates, Null values

# %%
ratings.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
ratings["userId"].nunique()
# Out:
# 610

# %%
ratings["userId"].count()
# Out:
# np.int64(100836)

# %%
ratings["movieId"].nunique()
# Out:
# 9724

# %%
ratings["rating"].value_counts().sort_index() #Rating distribution
# Out:
# rating
# 0.5     1370
# 1.0     2811
# 1.5     1791
# 2.0     7551
# 2.5     5550
# 3.0    20047
# 3.5    13136
# 4.0    26818
# 4.5     8551
# 5.0    13211
# Name: count, dtype: int64

# %% [markdown]
# Below cells gives insights about the User Activity

# %%
ratings["userId"].value_counts().head(10)
# Out:
# userId
# 414    2698
# 599    2478
# 474    2108
# 448    1864
# 274    1346
# 610    1302
# 68     1260
# 380    1218
# 606    1115
# 288    1055
# Name: count, dtype: int64

# %%
ratings["movieId"].value_counts().head(10) #Most rated movies

# Value Counts :- Counts how many times each value appears
# Out:
# movieId
# 356     329
# 318     317
# 296     307
# 593     279
# 2571    278
# 260     251
# 480     238
# 110     237
# 589     224
# 527     220
# Name: count, dtype: int64

# %%
ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09
